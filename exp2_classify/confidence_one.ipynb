# %%
# 导包
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from pandas import Series
from sklearn.preprocessing import LabelEncoder
import torch
import sys
sys.path.append("..")
import SGLN
import lassonet
from sklearn.linear_model import Lasso
from groupyr import SGL
from grouplasso import GroupLassoRegressor

# %%
# 加载数据
mnist = loadmat('../data/Mnist/mnist-original.mat')

X = mnist['data'].T               #这个一定要转置一下，因为这里面的行列是反的！！！！！
print(X.shape)
X = X / 255.
X = X / 100.
y = mnist['label'].T.flatten()     #将数据展开
y= Series(y.astype(np.uint8))              #将格式变为uint8

data = []
target = []
j = 0
for i in range(10):
    filter = y == i
    data.append(X[filter])
# Out:
# (70000, 784)

# %%
# 构建数据
sample_num = 100
X_train = []
y_train = []


for i in range(0, 10):
     X_train += list(data[i])[0 : sample_num]

X_train = np.array(X_train).T
y_train = list(data[0])[100]

# %%
# 分组信息
Groups = []

for i in range(10):
     group = np.arange(start=i*sample_num, stop = (i+1)*sample_num, step=1)
     Groups.append(group)

# # 将特征组列表转换为数组格式
# group_array = np.zeros(1000, dtype=int)
# for i, group in enumerate(Groups):
#     group_array[group] = i

# %%
# SGLN
fig_name = "SGLN"
model = SGLN.LassoNetRegressor(
    hidden_dims=(100,),
    #n_iters=(3000, 500),   # 控制epochs
    lambda_start=0.2,
    path_multiplier=1.02,   # 控制Lambda_1变化趋势
    alpha=0.2,
    verbose=True,
    #patience=(100, 5)
)
path = model.path(X_train, y_train, Groups = Groups)
# Out:
# Initialized dense model
# 1000 epochs, val_objective 5.12e-07, val_loss 5.12e-07, regularization 0.00e+00, l2_regularization 3.21e-01
# -------------------------- 1 --------------------------
# Lambda_ = 0.20, selected 1000 features
# 100 epochs, val_objective 7.30e-01, val_loss 5.25e-07, regularization 7.30e-01, l2_regularization 3.21e-01
# -------------------------- 2 --------------------------
# Lambda_ = 0.20, selected 1000 features
# 100 epochs, val_objective 5.79e-01, val_loss 5.99e-07, regularization 5.79e-01, l2_regularization 3.21e-01
# -------------------------- 3 --------------------------
# Lambda_ = 0.21, selected 1000 features
# 100 epochs, val_objective 4.53e-01, val_loss 7.84e-07, regularization 4.53e-01, l2_regularization 3.21e-01
# -------------------------- 4 --------------------------
# Lambda_ = 0.21, selected 1000 features
# 100 epochs, val_objective 3.55e-01, val_loss 9.80e-07, regularization 3.55e-01, l2_regularization 3.21e-01
# -------------------------- 5 --------------------------
# Lambda_ = 0.22, selected 1000 features
# 100 epochs, val_objective 2.88e-01, val_loss 1.12e-06, regularization 2.88e-01, l2_regularization 3.21e-01
# -------------------------- 6 --------------------------
# Lambda_ = 0.22, selected 1000 features
# 93 epochs, val_objective 2.59e-01, val_loss 1.25e-06, regularization 2.59e-01, l2_regularization 3.21e-01
# -------------------------- 7 --------------------------
# Lambda_ = 0.23, selected 1000 features
# 10 epochs, val_objective 2.61e-01, val_loss 1.27e-06, regularization 2.61e-01, l2_regularization 3.21e-01
# -------------------------- 8 --------------------------
# Lambda_ = 0.23, selected 1000 features
# 10 epochs, val_objective 2.64e-01, val_loss 1.28e-06, regularization 2.64e-01, l2_regularization 3.21e-01
# -------------------------- 9 --------------------------
# Lambda_ = 0.23, selected 1000 features
# 10 epochs, val_objective 2.67e-01, val_loss 1.29e-06, regularization 2.67e-01, l2_regularization 3.21e-01
# -------------------------- 10 --------------------------
# Lambda_ = 0.24, selected 1000 features
# 10 epochs, val_objective 2.71e-01, val_loss 1.30e-06, regularization 2.71e-01, l2_regularization 3.21e-01
# -------------------------- 11 --------------------------
# Lambda_ = 0.24, selected 1000 features
# 10 epochs, val_objective 2.74e-01, val_loss 1.31e-06, regularization 2.74e-01, l2_regularization 3.21e-01
# -------------------------- 12 --------------------------
# Lambda_ = 0.25, selected 1000 features
# 10 epochs, val_objective 2.78e-01, val_loss 1.31e-06, regularization 2.78e-01, l2_regularization 3.21e-01
# -------------------------- 13 --------------------------
# Lambda_ = 0.25, selected 1000 features
# 10 epochs, val_objective 2.82e-01, val_loss 1.32e-06, regularization 2.82e-01, l2_regularization 3.21e-01
# -------------------------- 14 --------------------------
# Lambda_ = 0.26, selected 1000 features
# 10 epochs, val_objective 2.86e-01, val_loss 1.33e-06, regularization 2.86e-01, l2_regularization 3.21e-01
# -------------------------- 15 --------------------------
# Lambda_ = 0.26, selected 1000 features
# 10 epochs, val_objective 2.90e-01, val_loss 1.34e-06, regularization 2.90e-01, l2_regularization 3.21e-01
# -------------------------- 16 --------------------------
# Lambda_ = 0.27, selected 1000 features
# 10 epochs, val_objective 2.94e-01, val_loss 1.34e-06, regularization 2.94e-01, l2_regularization 3.21e-01
# -------------------------- 17 --------------------------
# Lambda_ = 0.27, selected 1000 features
# 10 epochs, val_objective 2.99e-01, val_loss 1.35e-06, regularization 2.99e-01, l2_regularization 3.21e-01
# -------------------------- 18 --------------------------
# Lambda_ = 0.28, selected 1000 features
# 10 epochs, val_objective 3.03e-01, val_loss 1.36e-06, regularization 3.03e-01, l2_regularization 3.21e-01
# -------------------------- 19 --------------------------
# Lambda_ = 0.29, selected 1000 features
# 10 epochs, val_objective 3.08e-01, val_loss 1.36e-06, regularization 3.08e-01, l2_regularization 3.21e-01
# -------------------------- 20 --------------------------
# Lambda_ = 0.29, selected 1000 features
# 10 epochs, val_objective 3.13e-01, val_loss 1.37e-06, regularization 3.13e-01, l2_regularization 3.21e-01
# -------------------------- 21 --------------------------
# Lambda_ = 0.30, selected 1000 features
# 10 epochs, val_objective 3.18e-01, val_loss 1.37e-06, regularization 3.18e-01, l2_regularization 3.21e-01
# -------------------------- 22 --------------------------
# Lambda_ = 0.30, selected 1000 features
# 10 epochs, val_objective 3.24e-01, val_loss 1.38e-06, regularization 3.24e-01, l2_regularization 3.21e-01
# -------------------------- 23 --------------------------
# Lambda_ = 0.31, selected 1000 features
# 10 epochs, val_objective 3.29e-01, val_loss 1.39e-06, regularization 3.29e-01, l2_regularization 3.21e-01
# -------------------------- 24 --------------------------
# Lambda_ = 0.32, selected 1000 features
# 10 epochs, val_objective 3.35e-01, val_loss 1.40e-06, regularization 3.35e-01, l2_regularization 3.21e-01
# -------------------------- 25 --------------------------
# Lambda_ = 0.32, selected 1000 features
# 10 epochs, val_objective 3.40e-01, val_loss 1.41e-06, regularization 3.40e-01, l2_regularization 3.21e-01
# -------------------------- 26 --------------------------
# Lambda_ = 0.33, selected 1000 features
# 10 epochs, val_objective 3.46e-01, val_loss 1.42e-06, regularization 3.46e-01, l2_regularization 3.21e-01
# -------------------------- 27 --------------------------
# Lambda_ = 0.33, selected 1000 features
# 10 epochs, val_objective 3.52e-01, val_loss 1.43e-06, regularization 3.52e-01, l2_regularization 3.21e-01
# -------------------------- 28 --------------------------
# Lambda_ = 0.34, selected 1000 features
# 10 epochs, val_objective 3.58e-01, val_loss 1.44e-06, regularization 3.58e-01, l2_regularization 3.21e-01
# -------------------------- 29 --------------------------
# Lambda_ = 0.35, selected 1000 features
# 10 epochs, val_objective 3.65e-01, val_loss 1.44e-06, regularization 3.65e-01, l2_regularization 3.21e-01
# -------------------------- 30 --------------------------
# Lambda_ = 0.36, selected 1000 features
# 10 epochs, val_objective 3.71e-01, val_loss 1.45e-06, regularization 3.71e-01, l2_regularization 3.21e-01
# -------------------------- 31 --------------------------
# Lambda_ = 0.36, selected 1000 features
# 10 epochs, val_objective 3.78e-01, val_loss 1.45e-06, regularization 3.78e-01, l2_regularization 3.21e-01
# -------------------------- 32 --------------------------
# Lambda_ = 0.37, selected 1000 features
# 10 epochs, val_objective 3.84e-01, val_loss 1.46e-06, regularization 3.84e-01, l2_regularization 3.21e-01
# -------------------------- 33 --------------------------
# Lambda_ = 0.38, selected 1000 features
# 10 epochs, val_objective 3.91e-01, val_loss 1.46e-06, regularization 3.91e-01, l2_regularization 3.21e-01
# -------------------------- 34 --------------------------
# Lambda_ = 0.38, selected 1000 features
# 10 epochs, val_objective 3.98e-01, val_loss 1.47e-06, regularization 3.98e-01, l2_regularization 3.21e-01
# -------------------------- 35 --------------------------
# Lambda_ = 0.39, selected 1000 features
# 10 epochs, val_objective 4.05e-01, val_loss 1.47e-06, regularization 4.05e-01, l2_regularization 3.21e-01
# -------------------------- 36 --------------------------
# Lambda_ = 0.40, selected 1000 features
# 10 epochs, val_objective 4.12e-01, val_loss 1.48e-06, regularization 4.12e-01, l2_regularization 3.21e-01
# -------------------------- 37 --------------------------
# Lambda_ = 0.41, selected 1000 features
# 10 epochs, val_objective 4.19e-01, val_loss 1.49e-06, regularization 4.19e-01, l2_regularization 3.21e-01
# -------------------------- 38 --------------------------
# Lambda_ = 0.42, selected 1000 features
# 10 epochs, val_objective 4.27e-01, val_loss 1.49e-06, regularization 4.27e-01, l2_regularization 3.21e-01
# -------------------------- 39 --------------------------
# Lambda_ = 0.42, selected 1000 features
# 10 epochs, val_objective 4.34e-01, val_loss 1.50e-06, regularization 4.34e-01, l2_regularization 3.21e-01
# -------------------------- 40 --------------------------
# Lambda_ = 0.43, selected 1000 features
# 10 epochs, val_objective 4.42e-01, val_loss 1.50e-06, regularization 4.42e-01, l2_regularization 3.21e-01
# -------------------------- 41 --------------------------
# Lambda_ = 0.44, selected 1000 features
# 10 epochs, val_objective 4.49e-01, val_loss 1.51e-06, regularization 4.49e-01, l2_regularization 3.21e-01
# -------------------------- 42 --------------------------
# Lambda_ = 0.45, selected 1000 features
# 10 epochs, val_objective 4.57e-01, val_loss 1.52e-06, regularization 4.57e-01, l2_regularization 3.21e-01
# -------------------------- 43 --------------------------
# Lambda_ = 0.46, selected 1000 features
# 10 epochs, val_objective 4.65e-01, val_loss 1.53e-06, regularization 4.65e-01, l2_regularization 3.21e-01
# -------------------------- 44 --------------------------
# Lambda_ = 0.47, selected 1000 features
# 10 epochs, val_objective 4.73e-01, val_loss 1.53e-06, regularization 4.73e-01, l2_regularization 3.21e-01
# -------------------------- 45 --------------------------
# Lambda_ = 0.48, selected 1000 features
# 10 epochs, val_objective 4.82e-01, val_loss 1.54e-06, regularization 4.82e-01, l2_regularization 3.21e-01
# -------------------------- 46 --------------------------
# Lambda_ = 0.49, selected 1000 features
# 10 epochs, val_objective 4.90e-01, val_loss 1.55e-06, regularization 4.90e-01, l2_regularization 3.21e-01
# -------------------------- 47 --------------------------
# Lambda_ = 0.50, selected 1000 features
# 10 epochs, val_objective 4.99e-01, val_loss 1.55e-06, regularization 4.99e-01, l2_regularization 3.21e-01
# -------------------------- 48 --------------------------
# Lambda_ = 0.51, selected 1000 features
# 10 epochs, val_objective 5.08e-01, val_loss 1.56e-06, regularization 5.08e-01, l2_regularization 3.21e-01
# -------------------------- 49 --------------------------
# Lambda_ = 0.52, selected 1000 features
# 10 epochs, val_objective 5.17e-01, val_loss 1.56e-06, regularization 5.17e-01, l2_regularization 3.21e-01
# -------------------------- 50 --------------------------
# Lambda_ = 0.53, selected 1000 features
# 10 epochs, val_objective 5.26e-01, val_loss 1.57e-06, regularization 5.26e-01, l2_regularization 3.21e-01
# -------------------------- 51 --------------------------
# Lambda_ = 0.54, selected 1000 features
# 10 epochs, val_objective 5.35e-01, val_loss 1.57e-06, regularization 5.35e-01, l2_regularization 3.21e-01
# -------------------------- 52 --------------------------
# Lambda_ = 0.55, selected 1000 features
# 10 epochs, val_objective 5.45e-01, val_loss 1.58e-06, regularization 5.45e-01, l2_regularization 3.21e-01
# -------------------------- 53 --------------------------
# Lambda_ = 0.56, selected 1000 features
# 10 epochs, val_objective 5.54e-01, val_loss 1.58e-06, regularization 5.54e-01, l2_regularization 3.21e-01
# -------------------------- 54 --------------------------
# Lambda_ = 0.57, selected 1000 features
# 10 epochs, val_objective 5.64e-01, val_loss 1.59e-06, regularization 5.64e-01, l2_regularization 3.21e-01
# -------------------------- 55 --------------------------
# Lambda_ = 0.58, selected 1000 features
# 10 epochs, val_objective 5.74e-01, val_loss 1.60e-06, regularization 5.74e-01, l2_regularization 3.21e-01
# -------------------------- 56 --------------------------
# Lambda_ = 0.59, selected 1000 features
# 10 epochs, val_objective 5.84e-01, val_loss 1.60e-06, regularization 5.84e-01, l2_regularization 3.21e-01
# -------------------------- 57 --------------------------
# Lambda_ = 0.61, selected 1000 features
# 10 epochs, val_objective 5.95e-01, val_loss 1.61e-06, regularization 5.95e-01, l2_regularization 3.21e-01
# -------------------------- 58 --------------------------
# Lambda_ = 0.62, selected 1000 features
# 10 epochs, val_objective 6.05e-01, val_loss 1.61e-06, regularization 6.05e-01, l2_regularization 3.21e-01
# -------------------------- 59 --------------------------
# Lambda_ = 0.63, selected 1000 features
# 10 epochs, val_objective 6.16e-01, val_loss 1.62e-06, regularization 6.16e-01, l2_regularization 3.21e-01
# -------------------------- 60 --------------------------
# Lambda_ = 0.64, selected 1000 features
# 10 epochs, val_objective 6.27e-01, val_loss 1.62e-06, regularization 6.27e-01, l2_regularization 3.21e-01
# -------------------------- 61 --------------------------
# Lambda_ = 0.66, selected 1000 features
# 10 epochs, val_objective 6.38e-01, val_loss 1.63e-06, regularization 6.38e-01, l2_regularization 3.21e-01
# -------------------------- 62 --------------------------
# Lambda_ = 0.67, selected 1000 features
# 10 epochs, val_objective 6.50e-01, val_loss 1.63e-06, regularization 6.50e-01, l2_regularization 3.21e-01
# -------------------------- 63 --------------------------
# Lambda_ = 0.68, selected 1000 features
# 10 epochs, val_objective 6.62e-01, val_loss 1.63e-06, regularization 6.62e-01, l2_regularization 3.21e-01
# -------------------------- 64 --------------------------
# Lambda_ = 0.70, selected 1000 features
# 10 epochs, val_objective 6.74e-01, val_loss 1.63e-06, regularization 6.74e-01, l2_regularization 3.21e-01
# -------------------------- 65 --------------------------
# Lambda_ = 0.71, selected 1000 features
# 10 epochs, val_objective 6.86e-01, val_loss 1.63e-06, regularization 6.86e-01, l2_regularization 3.21e-01
# -------------------------- 66 --------------------------
# Lambda_ = 0.72, selected 1000 features
# 10 epochs, val_objective 6.98e-01, val_loss 1.63e-06, regularization 6.98e-01, l2_regularization 3.21e-01
# -------------------------- 67 --------------------------
# Lambda_ = 0.74, selected 1000 features
# 10 epochs, val_objective 7.11e-01, val_loss 1.63e-06, regularization 7.11e-01, l2_regularization 3.21e-01
# -------------------------- 68 --------------------------
# Lambda_ = 0.75, selected 1000 features
# 10 epochs, val_objective 7.24e-01, val_loss 1.64e-06, regularization 7.24e-01, l2_regularization 3.21e-01
# -------------------------- 69 --------------------------
# Lambda_ = 0.77, selected 1000 features
# 10 epochs, val_objective 7.37e-01, val_loss 1.64e-06, regularization 7.37e-01, l2_regularization 3.21e-01
# -------------------------- 70 --------------------------
# Lambda_ = 0.78, selected 1000 features
# 10 epochs, val_objective 7.50e-01, val_loss 1.64e-06, regularization 7.50e-01, l2_regularization 3.21e-01
# -------------------------- 71 --------------------------
# Lambda_ = 0.80, selected 1000 features
# 10 epochs, val_objective 7.64e-01, val_loss 1.64e-06, regularization 7.64e-01, l2_regularization 3.21e-01
# -------------------------- 72 --------------------------
# Lambda_ = 0.82, selected 1000 features
# 10 epochs, val_objective 7.78e-01, val_loss 1.64e-06, regularization 7.78e-01, l2_regularization 3.21e-01
# -------------------------- 73 --------------------------
# Lambda_ = 0.83, selected 1000 features
# 10 epochs, val_objective 7.92e-01, val_loss 1.64e-06, regularization 7.92e-01, l2_regularization 3.21e-01
# -------------------------- 74 --------------------------
# Lambda_ = 0.85, selected 1000 features
# 10 epochs, val_objective 8.06e-01, val_loss 1.65e-06, regularization 8.06e-01, l2_regularization 3.21e-01
# -------------------------- 75 --------------------------
# Lambda_ = 0.87, selected 1000 features
# 10 epochs, val_objective 8.21e-01, val_loss 1.65e-06, regularization 8.21e-01, l2_regularization 3.21e-01
# -------------------------- 76 --------------------------
# Lambda_ = 0.88, selected 1000 features
# 10 epochs, val_objective 8.36e-01, val_loss 1.65e-06, regularization 8.36e-01, l2_regularization 3.21e-01
# -------------------------- 77 --------------------------
# Lambda_ = 0.90, selected 1000 features
# 10 epochs, val_objective 8.51e-01, val_loss 1.65e-06, regularization 8.51e-01, l2_regularization 3.21e-01
# -------------------------- 78 --------------------------
# Lambda_ = 0.92, selected 1000 features
# 10 epochs, val_objective 8.66e-01, val_loss 1.65e-06, regularization 8.66e-01, l2_regularization 3.21e-01
# -------------------------- 79 --------------------------
# Lambda_ = 0.94, selected 1000 features
# 10 epochs, val_objective 8.82e-01, val_loss 1.66e-06, regularization 8.82e-01, l2_regularization 3.21e-01
# -------------------------- 80 --------------------------
# Lambda_ = 0.96, selected 1000 features
# 10 epochs, val_objective 8.98e-01, val_loss 1.66e-06, regularization 8.98e-01, l2_regularization 3.21e-01
# -------------------------- 81 --------------------------
# Lambda_ = 0.98, selected 1000 features
# 10 epochs, val_objective 9.14e-01, val_loss 1.66e-06, regularization 9.14e-01, l2_regularization 3.21e-01
# -------------------------- 82 --------------------------
# Lambda_ = 0.99, selected 1000 features
# 10 epochs, val_objective 9.30e-01, val_loss 1.66e-06, regularization 9.30e-01, l2_regularization 3.21e-01
# -------------------------- 83 --------------------------
# Lambda_ = 1.01, selected 1000 features
# 10 epochs, val_objective 9.47e-01, val_loss 1.66e-06, regularization 9.47e-01, l2_regularization 3.21e-01
# -------------------------- 84 --------------------------
# Lambda_ = 1.03, selected 1000 features
# 10 epochs, val_objective 9.64e-01, val_loss 1.67e-06, regularization 9.64e-01, l2_regularization 3.21e-01
# -------------------------- 85 --------------------------
# Lambda_ = 1.06, selected 1000 features
# 10 epochs, val_objective 9.81e-01, val_loss 1.67e-06, regularization 9.81e-01, l2_regularization 3.21e-01
# -------------------------- 86 --------------------------
# Lambda_ = 1.08, selected 1000 features
# 10 epochs, val_objective 9.99e-01, val_loss 1.67e-06, regularization 9.99e-01, l2_regularization 3.21e-01
# -------------------------- 87 --------------------------
# Lambda_ = 1.10, selected 1000 features
# 10 epochs, val_objective 1.02e+00, val_loss 1.67e-06, regularization 1.02e+00, l2_regularization 3.21e-01
# -------------------------- 88 --------------------------
# Lambda_ = 1.12, selected 1000 features
# 10 epochs, val_objective 1.04e+00, val_loss 1.67e-06, regularization 1.04e+00, l2_regularization 3.21e-01
# -------------------------- 89 --------------------------
# Lambda_ = 1.14, selected 1000 features
# 10 epochs, val_objective 1.05e+00, val_loss 1.68e-06, regularization 1.05e+00, l2_regularization 3.21e-01
# -------------------------- 90 --------------------------
# Lambda_ = 1.17, selected 1000 features
# 10 epochs, val_objective 1.07e+00, val_loss 1.68e-06, regularization 1.07e+00, l2_regularization 3.21e-01
# -------------------------- 91 --------------------------
# Lambda_ = 1.19, selected 1000 features
# 10 epochs, val_objective 1.09e+00, val_loss 1.68e-06, regularization 1.09e+00, l2_regularization 3.21e-01
# -------------------------- 92 --------------------------
# Lambda_ = 1.21, selected 1000 features
# 10 epochs, val_objective 1.11e+00, val_loss 1.68e-06, regularization 1.11e+00, l2_regularization 3.21e-01
# -------------------------- 93 --------------------------
# Lambda_ = 1.24, selected 1000 features
# 10 epochs, val_objective 1.13e+00, val_loss 1.69e-06, regularization 1.13e+00, l2_regularization 3.21e-01
# -------------------------- 94 --------------------------
# Lambda_ = 1.26, selected 1000 features
# 10 epochs, val_objective 1.15e+00, val_loss 1.69e-06, regularization 1.15e+00, l2_regularization 3.21e-01
# -------------------------- 95 --------------------------
# Lambda_ = 1.29, selected 1000 features
# 10 epochs, val_objective 1.17e+00, val_loss 1.69e-06, regularization 1.17e+00, l2_regularization 3.21e-01
# -------------------------- 96 --------------------------
# Lambda_ = 1.31, selected 1000 features
# 10 epochs, val_objective 1.19e+00, val_loss 1.69e-06, regularization 1.19e+00, l2_regularization 3.21e-01
# -------------------------- 97 --------------------------
# Lambda_ = 1.34, selected 1000 features
# 10 epochs, val_objective 1.21e+00, val_loss 1.70e-06, regularization 1.21e+00, l2_regularization 3.21e-01
# -------------------------- 98 --------------------------
# Lambda_ = 1.37, selected 1000 features
# 10 epochs, val_objective 1.24e+00, val_loss 1.70e-06, regularization 1.24e+00, l2_regularization 3.21e-01
# -------------------------- 99 --------------------------
# Lambda_ = 1.39, selected 1000 features
# 10 epochs, val_objective 1.26e+00, val_loss 1.70e-06, regularization 1.26e+00, l2_regularization 3.21e-01
# -------------------------- 100 --------------------------
# Lambda_ = 1.42, selected 1000 features
# 10 epochs, val_objective 1.28e+00, val_loss 1.70e-06, regularization 1.28e+00, l2_regularization 3.21e-01
# -------------------------- 101 --------------------------
# Lambda_ = 1.45, selected 1000 features
# 10 epochs, val_objective 1.30e+00, val_loss 1.71e-06, regularization 1.30e+00, l2_regularization 3.21e-01
# -------------------------- 102 --------------------------
# Lambda_ = 1.48, selected 1000 features
# 10 epochs, val_objective 1.33e+00, val_loss 1.71e-06, regularization 1.33e+00, l2_regularization 3.21e-01
# -------------------------- 103 --------------------------
# Lambda_ = 1.51, selected 1000 features
# 10 epochs, val_objective 1.35e+00, val_loss 1.71e-06, regularization 1.35e+00, l2_regularization 3.21e-01
# -------------------------- 104 --------------------------
# Lambda_ = 1.54, selected 1000 features
# 10 epochs, val_objective 1.37e+00, val_loss 1.72e-06, regularization 1.37e+00, l2_regularization 3.21e-01
# -------------------------- 105 --------------------------
# Lambda_ = 1.57, selected 1000 features
# 10 epochs, val_objective 1.40e+00, val_loss 1.72e-06, regularization 1.40e+00, l2_regularization 3.21e-01
# -------------------------- 106 --------------------------
# Lambda_ = 1.60, selected 1000 features
# 10 epochs, val_objective 1.42e+00, val_loss 1.72e-06, regularization 1.42e+00, l2_regularization 3.21e-01
# -------------------------- 107 --------------------------
# Lambda_ = 1.63, selected 1000 features
# 10 epochs, val_objective 1.45e+00, val_loss 1.72e-06, regularization 1.45e+00, l2_regularization 3.21e-01
# -------------------------- 108 --------------------------
# Lambda_ = 1.66, selected 1000 features
# 10 epochs, val_objective 1.47e+00, val_loss 1.73e-06, regularization 1.47e+00, l2_regularization 3.21e-01
# -------------------------- 109 --------------------------
# Lambda_ = 1.70, selected 1000 features
# 10 epochs, val_objective 1.50e+00, val_loss 1.73e-06, regularization 1.50e+00, l2_regularization 3.21e-01
# -------------------------- 110 --------------------------
# Lambda_ = 1.73, selected 1000 features
# 10 epochs, val_objective 1.53e+00, val_loss 1.73e-06, regularization 1.53e+00, l2_regularization 3.21e-01
# -------------------------- 111 --------------------------
# Lambda_ = 1.77, selected 1000 features
# 10 epochs, val_objective 1.55e+00, val_loss 1.74e-06, regularization 1.55e+00, l2_regularization 3.21e-01
# -------------------------- 112 --------------------------
# Lambda_ = 1.80, selected 1000 features
# 10 epochs, val_objective 1.58e+00, val_loss 1.74e-06, regularization 1.58e+00, l2_regularization 3.21e-01
# -------------------------- 113 --------------------------
# Lambda_ = 1.84, selected 1000 features
# 10 epochs, val_objective 1.61e+00, val_loss 1.74e-06, regularization 1.61e+00, l2_regularization 3.21e-01
# -------------------------- 114 --------------------------
# Lambda_ = 1.87, selected 1000 features
# 10 epochs, val_objective 1.64e+00, val_loss 1.75e-06, regularization 1.64e+00, l2_regularization 3.21e-01
# -------------------------- 115 --------------------------
# Lambda_ = 1.91, selected 1000 features
# 10 epochs, val_objective 1.67e+00, val_loss 1.75e-06, regularization 1.67e+00, l2_regularization 3.21e-01
# -------------------------- 116 --------------------------
# Lambda_ = 1.95, selected 1000 features
# 10 epochs, val_objective 1.70e+00, val_loss 1.75e-06, regularization 1.70e+00, l2_regularization 3.21e-01
# -------------------------- 117 --------------------------
# Lambda_ = 1.99, selected 1000 features
# 10 epochs, val_objective 1.73e+00, val_loss 1.75e-06, regularization 1.73e+00, l2_regularization 3.21e-01
# -------------------------- 118 --------------------------
# Lambda_ = 2.03, selected 1000 features
# 10 epochs, val_objective 1.76e+00, val_loss 1.76e-06, regularization 1.76e+00, l2_regularization 3.21e-01
# -------------------------- 119 --------------------------
# Lambda_ = 2.07, selected 1000 features
# 10 epochs, val_objective 1.79e+00, val_loss 1.76e-06, regularization 1.79e+00, l2_regularization 3.21e-01
# -------------------------- 120 --------------------------
# Lambda_ = 2.11, selected 1000 features
# 10 epochs, val_objective 1.82e+00, val_loss 1.77e-06, regularization 1.82e+00, l2_regularization 3.21e-01
# -------------------------- 121 --------------------------
# Lambda_ = 2.15, selected 1000 features
# 10 epochs, val_objective 1.85e+00, val_loss 1.77e-06, regularization 1.85e+00, l2_regularization 3.21e-01
# -------------------------- 122 --------------------------
# Lambda_ = 2.20, selected 1000 features
# 10 epochs, val_objective 1.88e+00, val_loss 1.77e-06, regularization 1.88e+00, l2_regularization 3.21e-01
# -------------------------- 123 --------------------------
# Lambda_ = 2.24, selected 1000 features
# 10 epochs, val_objective 1.92e+00, val_loss 1.78e-06, regularization 1.92e+00, l2_regularization 3.21e-01
# -------------------------- 124 --------------------------
# Lambda_ = 2.28, selected 1000 features
# 10 epochs, val_objective 1.95e+00, val_loss 1.78e-06, regularization 1.95e+00, l2_regularization 3.21e-01
# -------------------------- 125 --------------------------
# Lambda_ = 2.33, selected 1000 features
# 10 epochs, val_objective 1.98e+00, val_loss 1.78e-06, regularization 1.98e+00, l2_regularization 3.21e-01
# -------------------------- 126 --------------------------
# Lambda_ = 2.38, selected 1000 features
# 10 epochs, val_objective 2.02e+00, val_loss 1.79e-06, regularization 2.02e+00, l2_regularization 3.21e-01
# -------------------------- 127 --------------------------
# Lambda_ = 2.42, selected 1000 features
# 10 epochs, val_objective 2.05e+00, val_loss 1.79e-06, regularization 2.05e+00, l2_regularization 3.21e-01
# -------------------------- 128 --------------------------
# Lambda_ = 2.47, selected 1000 features
# 10 epochs, val_objective 2.09e+00, val_loss 1.80e-06, regularization 2.09e+00, l2_regularization 3.21e-01
# -------------------------- 129 --------------------------
# Lambda_ = 2.52, selected 1000 features
# 10 epochs, val_objective 2.13e+00, val_loss 1.80e-06, regularization 2.13e+00, l2_regularization 3.21e-01
# -------------------------- 130 --------------------------
# Lambda_ = 2.57, selected 1000 features
# 10 epochs, val_objective 2.16e+00, val_loss 1.80e-06, regularization 2.16e+00, l2_regularization 3.21e-01
# -------------------------- 131 --------------------------
# Lambda_ = 2.62, selected 1000 features
# 10 epochs, val_objective 2.20e+00, val_loss 1.81e-06, regularization 2.20e+00, l2_regularization 3.21e-01
# -------------------------- 132 --------------------------
# Lambda_ = 2.68, selected 1000 features
# 10 epochs, val_objective 2.24e+00, val_loss 1.81e-06, regularization 2.24e+00, l2_regularization 3.21e-01
# -------------------------- 133 --------------------------
# Lambda_ = 2.73, selected 1000 features
# 10 epochs, val_objective 2.28e+00, val_loss 1.81e-06, regularization 2.28e+00, l2_regularization 3.21e-01
# -------------------------- 134 --------------------------
# Lambda_ = 2.79, selected 1000 features
# 10 epochs, val_objective 2.32e+00, val_loss 1.82e-06, regularization 2.32e+00, l2_regularization 3.21e-01
# -------------------------- 135 --------------------------
# Lambda_ = 2.84, selected 1000 features
# 10 epochs, val_objective 2.36e+00, val_loss 1.82e-06, regularization 2.36e+00, l2_regularization 3.21e-01
# -------------------------- 136 --------------------------
# Lambda_ = 2.90, selected 1000 features
# 10 epochs, val_objective 2.40e+00, val_loss 1.83e-06, regularization 2.40e+00, l2_regularization 3.21e-01
# -------------------------- 137 --------------------------
# Lambda_ = 2.96, selected 1000 features
# 10 epochs, val_objective 2.44e+00, val_loss 1.83e-06, regularization 2.44e+00, l2_regularization 3.21e-01
# -------------------------- 138 --------------------------
# Lambda_ = 3.01, selected 1000 features
# 10 epochs, val_objective 2.48e+00, val_loss 1.84e-06, regularization 2.48e+00, l2_regularization 3.21e-01
# -------------------------- 139 --------------------------
# Lambda_ = 3.08, selected 1000 features
# 10 epochs, val_objective 2.53e+00, val_loss 1.84e-06, regularization 2.53e+00, l2_regularization 3.21e-01
# -------------------------- 140 --------------------------
# Lambda_ = 3.14, selected 1000 features
# 10 epochs, val_objective 2.57e+00, val_loss 1.84e-06, regularization 2.57e+00, l2_regularization 3.21e-01
# -------------------------- 141 --------------------------
# Lambda_ = 3.20, selected 1000 features
# 10 epochs, val_objective 2.62e+00, val_loss 1.85e-06, regularization 2.62e+00, l2_regularization 3.21e-01
# -------------------------- 142 --------------------------
# Lambda_ = 3.26, selected 1000 features
# 10 epochs, val_objective 2.66e+00, val_loss 1.85e-06, regularization 2.66e+00, l2_regularization 3.21e-01
# -------------------------- 143 --------------------------
# Lambda_ = 3.33, selected 1000 features
# 10 epochs, val_objective 2.71e+00, val_loss 1.86e-06, regularization 2.71e+00, l2_regularization 3.21e-01
# -------------------------- 144 --------------------------
# Lambda_ = 3.40, selected 1000 features
# 10 epochs, val_objective 2.75e+00, val_loss 1.86e-06, regularization 2.75e+00, l2_regularization 3.21e-01
# -------------------------- 145 --------------------------
# Lambda_ = 3.46, selected 1000 features
# 10 epochs, val_objective 2.80e+00, val_loss 1.87e-06, regularization 2.80e+00, l2_regularization 3.21e-01
# -------------------------- 146 --------------------------
# Lambda_ = 3.53, selected 1000 features
# 10 epochs, val_objective 2.85e+00, val_loss 1.87e-06, regularization 2.85e+00, l2_regularization 3.21e-01
# -------------------------- 147 --------------------------
# Lambda_ = 3.60, selected 1000 features
# 10 epochs, val_objective 2.90e+00, val_loss 1.88e-06, regularization 2.90e+00, l2_regularization 3.21e-01
# -------------------------- 148 --------------------------
# Lambda_ = 3.67, selected 1000 features
# 10 epochs, val_objective 2.95e+00, val_loss 1.88e-06, regularization 2.95e+00, l2_regularization 3.21e-01
# -------------------------- 149 --------------------------
# Lambda_ = 3.75, selected 1000 features
# 10 epochs, val_objective 3.00e+00, val_loss 1.89e-06, regularization 3.00e+00, l2_regularization 3.21e-01
# -------------------------- 150 --------------------------
# Lambda_ = 3.82, selected 1000 features
# 10 epochs, val_objective 3.05e+00, val_loss 1.89e-06, regularization 3.05e+00, l2_regularization 3.21e-01
# -------------------------- 151 --------------------------
# Lambda_ = 3.90, selected 1000 features
# 10 epochs, val_objective 3.10e+00, val_loss 1.90e-06, regularization 3.10e+00, l2_regularization 3.21e-01
# -------------------------- 152 --------------------------
# Lambda_ = 3.98, selected 1000 features
# 10 epochs, val_objective 3.15e+00, val_loss 1.90e-06, regularization 3.15e+00, l2_regularization 3.21e-01
# -------------------------- 153 --------------------------
# Lambda_ = 4.06, selected 1000 features
# 10 epochs, val_objective 3.21e+00, val_loss 1.91e-06, regularization 3.21e+00, l2_regularization 3.21e-01
# -------------------------- 154 --------------------------
# Lambda_ = 4.14, selected 1000 features
# 10 epochs, val_objective 3.26e+00, val_loss 1.91e-06, regularization 3.26e+00, l2_regularization 3.21e-01
# -------------------------- 155 --------------------------
# Lambda_ = 4.22, selected 1000 features
# 10 epochs, val_objective 3.32e+00, val_loss 1.92e-06, regularization 3.32e+00, l2_regularization 3.21e-01
# -------------------------- 156 --------------------------
# Lambda_ = 4.31, selected 1000 features
# 10 epochs, val_objective 3.37e+00, val_loss 1.92e-06, regularization 3.37e+00, l2_regularization 3.21e-01
# -------------------------- 157 --------------------------
# Lambda_ = 4.39, selected 1000 features
# 10 epochs, val_objective 3.43e+00, val_loss 1.93e-06, regularization 3.43e+00, l2_regularization 3.21e-01
# -------------------------- 158 --------------------------
# Lambda_ = 4.48, selected 1000 features
# 10 epochs, val_objective 3.49e+00, val_loss 1.93e-06, regularization 3.49e+00, l2_regularization 3.21e-01
# -------------------------- 159 --------------------------
# Lambda_ = 4.57, selected 1000 features
# 10 epochs, val_objective 3.55e+00, val_loss 1.94e-06, regularization 3.55e+00, l2_regularization 3.21e-01
# -------------------------- 160 --------------------------
# Lambda_ = 4.66, selected 1000 features
# 10 epochs, val_objective 3.61e+00, val_loss 1.95e-06, regularization 3.61e+00, l2_regularization 3.21e-01
# -------------------------- 161 --------------------------
# Lambda_ = 4.75, selected 1000 features
# 10 epochs, val_objective 3.67e+00, val_loss 1.95e-06, regularization 3.67e+00, l2_regularization 3.21e-01
# -------------------------- 162 --------------------------
# Lambda_ = 4.85, selected 1000 features
# 10 epochs, val_objective 3.73e+00, val_loss 1.96e-06, regularization 3.73e+00, l2_regularization 3.21e-01
# -------------------------- 163 --------------------------
# Lambda_ = 4.95, selected 1000 features
# 10 epochs, val_objective 3.79e+00, val_loss 1.96e-06, regularization 3.79e+00, l2_regularization 3.21e-01
# -------------------------- 164 --------------------------
# Lambda_ = 5.04, selected 1000 features
# 10 epochs, val_objective 3.85e+00, val_loss 1.97e-06, regularization 3.85e+00, l2_regularization 3.21e-01
# -------------------------- 165 --------------------------
# Lambda_ = 5.15, selected 1000 features
# 10 epochs, val_objective 3.92e+00, val_loss 1.98e-06, regularization 3.92e+00, l2_regularization 3.21e-01
# -------------------------- 166 --------------------------
# Lambda_ = 5.25, selected 1000 features
# 10 epochs, val_objective 3.98e+00, val_loss 1.98e-06, regularization 3.98e+00, l2_regularization 3.21e-01
# -------------------------- 167 --------------------------
# Lambda_ = 5.35, selected 1000 features
# 10 epochs, val_objective 4.05e+00, val_loss 1.99e-06, regularization 4.05e+00, l2_regularization 3.21e-01
# -------------------------- 168 --------------------------
# Lambda_ = 5.46, selected 1000 features
# 10 epochs, val_objective 4.12e+00, val_loss 2.00e-06, regularization 4.12e+00, l2_regularization 3.21e-01
# -------------------------- 169 --------------------------
# Lambda_ = 5.57, selected 1000 features
# 10 epochs, val_objective 4.19e+00, val_loss 2.00e-06, regularization 4.19e+00, l2_regularization 3.21e-01
# -------------------------- 170 --------------------------
# Lambda_ = 5.68, selected 1000 features
# 10 epochs, val_objective 4.25e+00, val_loss 2.01e-06, regularization 4.25e+00, l2_regularization 3.21e-01
# -------------------------- 171 --------------------------
# Lambda_ = 5.80, selected 1000 features
# 10 epochs, val_objective 4.32e+00, val_loss 2.02e-06, regularization 4.32e+00, l2_regularization 3.21e-01
# -------------------------- 172 --------------------------
# Lambda_ = 5.91, selected 1000 features
# 10 epochs, val_objective 4.40e+00, val_loss 2.03e-06, regularization 4.40e+00, l2_regularization 3.21e-01
# -------------------------- 173 --------------------------
# Lambda_ = 6.03, selected 1000 features
# 10 epochs, val_objective 4.47e+00, val_loss 2.03e-06, regularization 4.47e+00, l2_regularization 3.21e-01
# -------------------------- 174 --------------------------
# Lambda_ = 6.15, selected 1000 features
# 10 epochs, val_objective 4.54e+00, val_loss 2.04e-06, regularization 4.54e+00, l2_regularization 3.21e-01
# -------------------------- 175 --------------------------
# Lambda_ = 6.27, selected 1000 features
# 10 epochs, val_objective 4.62e+00, val_loss 2.05e-06, regularization 4.62e+00, l2_regularization 3.21e-01
# -------------------------- 176 --------------------------
# Lambda_ = 6.40, selected 1000 features
# 10 epochs, val_objective 4.69e+00, val_loss 2.06e-06, regularization 4.69e+00, l2_regularization 3.21e-01
# -------------------------- 177 --------------------------
# Lambda_ = 6.53, selected 1000 features
# 10 epochs, val_objective 4.77e+00, val_loss 2.07e-06, regularization 4.77e+00, l2_regularization 3.21e-01
# -------------------------- 178 --------------------------
# Lambda_ = 6.66, selected 1000 features
# 10 epochs, val_objective 4.84e+00, val_loss 2.07e-06, regularization 4.84e+00, l2_regularization 3.21e-01
# -------------------------- 179 --------------------------
# Lambda_ = 6.79, selected 1000 features
# 10 epochs, val_objective 4.92e+00, val_loss 2.08e-06, regularization 4.92e+00, l2_regularization 3.21e-01
# -------------------------- 180 --------------------------
# Lambda_ = 6.93, selected 1000 features
# 10 epochs, val_objective 5.00e+00, val_loss 2.09e-06, regularization 5.00e+00, l2_regularization 3.21e-01
# -------------------------- 181 --------------------------
# Lambda_ = 7.06, selected 1000 features
# 10 epochs, val_objective 5.08e+00, val_loss 2.10e-06, regularization 5.08e+00, l2_regularization 3.21e-01
# -------------------------- 182 --------------------------
# Lambda_ = 7.21, selected 1000 features
# 10 epochs, val_objective 5.16e+00, val_loss 2.11e-06, regularization 5.16e+00, l2_regularization 3.21e-01
# -------------------------- 183 --------------------------
# Lambda_ = 7.35, selected 1000 features
# 10 epochs, val_objective 5.25e+00, val_loss 2.12e-06, regularization 5.25e+00, l2_regularization 3.21e-01
# -------------------------- 184 --------------------------
# Lambda_ = 7.50, selected 1000 features
# 10 epochs, val_objective 5.33e+00, val_loss 2.13e-06, regularization 5.33e+00, l2_regularization 3.21e-01
# -------------------------- 185 --------------------------
# Lambda_ = 7.65, selected 1000 features
# 10 epochs, val_objective 5.42e+00, val_loss 2.14e-06, regularization 5.42e+00, l2_regularization 3.21e-01
# -------------------------- 186 --------------------------
# Lambda_ = 7.80, selected 1000 features
# 10 epochs, val_objective 5.50e+00, val_loss 2.15e-06, regularization 5.50e+00, l2_regularization 3.21e-01
# -------------------------- 187 --------------------------
# Lambda_ = 7.96, selected 1000 features
# 10 epochs, val_objective 5.59e+00, val_loss 2.16e-06, regularization 5.59e+00, l2_regularization 3.21e-01
# -------------------------- 188 --------------------------
# Lambda_ = 8.11, selected 1000 features
# 10 epochs, val_objective 5.68e+00, val_loss 2.17e-06, regularization 5.68e+00, l2_regularization 3.21e-01
# -------------------------- 189 --------------------------
# Lambda_ = 8.28, selected 1000 features
# 10 epochs, val_objective 5.77e+00, val_loss 2.18e-06, regularization 5.77e+00, l2_regularization 3.21e-01
# -------------------------- 190 --------------------------
# Lambda_ = 8.44, selected 1000 features
# 10 epochs, val_objective 5.86e+00, val_loss 2.19e-06, regularization 5.86e+00, l2_regularization 3.21e-01
# -------------------------- 191 --------------------------
# Lambda_ = 8.61, selected 1000 features
# 10 epochs, val_objective 5.95e+00, val_loss 2.20e-06, regularization 5.95e+00, l2_regularization 3.21e-01
# -------------------------- 192 --------------------------
# Lambda_ = 8.78, selected 1000 features
# 10 epochs, val_objective 6.04e+00, val_loss 2.21e-06, regularization 6.04e+00, l2_regularization 3.21e-01
# -------------------------- 193 --------------------------
# Lambda_ = 8.96, selected 1000 features
# 10 epochs, val_objective 6.14e+00, val_loss 2.22e-06, regularization 6.14e+00, l2_regularization 3.21e-01
# -------------------------- 194 --------------------------
# Lambda_ = 9.14, selected 1000 features
# 10 epochs, val_objective 6.23e+00, val_loss 2.23e-06, regularization 6.23e+00, l2_regularization 3.21e-01
# -------------------------- 195 --------------------------
# Lambda_ = 9.32, selected 1000 features
# 10 epochs, val_objective 6.33e+00, val_loss 2.24e-06, regularization 6.33e+00, l2_regularization 3.21e-01
# -------------------------- 196 --------------------------
# Lambda_ = 9.51, selected 1000 features
# 10 epochs, val_objective 6.43e+00, val_loss 2.25e-06, regularization 6.43e+00, l2_regularization 3.21e-01
# -------------------------- 197 --------------------------
# Lambda_ = 9.70, selected 1000 features
# 10 epochs, val_objective 6.53e+00, val_loss 2.26e-06, regularization 6.53e+00, l2_regularization 3.21e-01
# -------------------------- 198 --------------------------
# Lambda_ = 9.89, selected 1000 features
# 10 epochs, val_objective 6.63e+00, val_loss 2.28e-06, regularization 6.63e+00, l2_regularization 3.21e-01
# -------------------------- 199 --------------------------
# Lambda_ = 10.09, selected 1000 features
# 10 epochs, val_objective 6.73e+00, val_loss 2.29e-06, regularization 6.73e+00, l2_regularization 3.21e-01
# -------------------------- 200 --------------------------
# Lambda_ = 10.29, selected 1000 features
# 10 epochs, val_objective 6.83e+00, val_loss 2.30e-06, regularization 6.83e+00, l2_regularization 3.21e-01
# -------------------------- 201 --------------------------
# Lambda_ = 10.50, selected 1000 features
# 10 epochs, val_objective 6.93e+00, val_loss 2.31e-06, regularization 6.93e+00, l2_regularization 3.21e-01
# -------------------------- 202 --------------------------
# Lambda_ = 10.71, selected 1000 features
# 10 epochs, val_objective 7.04e+00, val_loss 2.32e-06, regularization 7.04e+00, l2_regularization 3.21e-01
# -------------------------- 203 --------------------------
# Lambda_ = 10.92, selected 1000 features
# 10 epochs, val_objective 7.14e+00, val_loss 2.34e-06, regularization 7.14e+00, l2_regularization 3.21e-01
# -------------------------- 204 --------------------------
# Lambda_ = 11.14, selected 1000 features
# 10 epochs, val_objective 7.25e+00, val_loss 2.35e-06, regularization 7.25e+00, l2_regularization 3.21e-01
# -------------------------- 205 --------------------------
# Lambda_ = 11.36, selected 1000 features
# 10 epochs, val_objective 7.36e+00, val_loss 2.36e-06, regularization 7.36e+00, l2_regularization 3.21e-01
# -------------------------- 206 --------------------------
# Lambda_ = 11.59, selected 1000 features
# 10 epochs, val_objective 7.47e+00, val_loss 2.37e-06, regularization 7.47e+00, l2_regularization 3.21e-01
# -------------------------- 207 --------------------------
# Lambda_ = 11.82, selected 1000 features
# 10 epochs, val_objective 7.58e+00, val_loss 2.39e-06, regularization 7.58e+00, l2_regularization 3.21e-01
# -------------------------- 208 --------------------------
# Lambda_ = 12.06, selected 1000 features
# 10 epochs, val_objective 7.69e+00, val_loss 2.40e-06, regularization 7.69e+00, l2_regularization 3.21e-01
# -------------------------- 209 --------------------------
# Lambda_ = 12.30, selected 1000 features
# 10 epochs, val_objective 7.80e+00, val_loss 2.41e-06, regularization 7.80e+00, l2_regularization 3.21e-01
# -------------------------- 210 --------------------------
# Lambda_ = 12.54, selected 1000 features
# 10 epochs, val_objective 7.92e+00, val_loss 2.43e-06, regularization 7.92e+00, l2_regularization 3.21e-01
# -------------------------- 211 --------------------------
# Lambda_ = 12.80, selected 1000 features
# 10 epochs, val_objective 8.03e+00, val_loss 2.44e-06, regularization 8.03e+00, l2_regularization 3.21e-01
# -------------------------- 212 --------------------------
# Lambda_ = 13.05, selected 1000 features
# 10 epochs, val_objective 8.15e+00, val_loss 2.46e-06, regularization 8.15e+00, l2_regularization 3.21e-01
# -------------------------- 213 --------------------------
# Lambda_ = 13.31, selected 1000 features
# 10 epochs, val_objective 8.26e+00, val_loss 2.47e-06, regularization 8.26e+00, l2_regularization 3.21e-01
# -------------------------- 214 --------------------------
# Lambda_ = 13.58, selected 1000 features
# 10 epochs, val_objective 8.38e+00, val_loss 2.49e-06, regularization 8.38e+00, l2_regularization 3.21e-01
# -------------------------- 215 --------------------------
# Lambda_ = 13.85, selected 1000 features
# 10 epochs, val_objective 8.50e+00, val_loss 2.51e-06, regularization 8.50e+00, l2_regularization 3.21e-01
# -------------------------- 216 --------------------------
# Lambda_ = 14.13, selected 1000 features
# 10 epochs, val_objective 8.62e+00, val_loss 2.52e-06, regularization 8.62e+00, l2_regularization 3.21e-01
# -------------------------- 217 --------------------------
# Lambda_ = 14.41, selected 1000 features
# 10 epochs, val_objective 8.74e+00, val_loss 2.54e-06, regularization 8.74e+00, l2_regularization 3.21e-01
# -------------------------- 218 --------------------------
# Lambda_ = 14.70, selected 1000 features
# 10 epochs, val_objective 8.86e+00, val_loss 2.56e-06, regularization 8.86e+00, l2_regularization 3.21e-01
# -------------------------- 219 --------------------------
# Lambda_ = 14.99, selected 1000 features
# 10 epochs, val_objective 8.99e+00, val_loss 2.58e-06, regularization 8.99e+00, l2_regularization 3.21e-01
# -------------------------- 220 --------------------------
# Lambda_ = 15.29, selected 1000 features
# 10 epochs, val_objective 9.11e+00, val_loss 2.59e-06, regularization 9.11e+00, l2_regularization 3.21e-01
# -------------------------- 221 --------------------------
# Lambda_ = 15.60, selected 1000 features
# 10 epochs, val_objective 9.24e+00, val_loss 2.61e-06, regularization 9.24e+00, l2_regularization 3.21e-01
# -------------------------- 222 --------------------------
# Lambda_ = 15.91, selected 1000 features
# 10 epochs, val_objective 9.36e+00, val_loss 2.63e-06, regularization 9.36e+00, l2_regularization 3.21e-01
# -------------------------- 223 --------------------------
# Lambda_ = 16.23, selected 1000 features
# 10 epochs, val_objective 9.49e+00, val_loss 2.65e-06, regularization 9.49e+00, l2_regularization 3.21e-01
# -------------------------- 224 --------------------------
# Lambda_ = 16.55, selected 1000 features
# 10 epochs, val_objective 9.62e+00, val_loss 2.67e-06, regularization 9.62e+00, l2_regularization 3.21e-01
# -------------------------- 225 --------------------------
# Lambda_ = 16.88, selected 1000 features
# 10 epochs, val_objective 9.75e+00, val_loss 2.70e-06, regularization 9.75e+00, l2_regularization 3.21e-01
# -------------------------- 226 --------------------------
# Lambda_ = 17.22, selected 1000 features
# 10 epochs, val_objective 9.87e+00, val_loss 2.72e-06, regularization 9.87e+00, l2_regularization 3.21e-01
# -------------------------- 227 --------------------------
# Lambda_ = 17.57, selected 1000 features
# 10 epochs, val_objective 1.00e+01, val_loss 2.74e-06, regularization 1.00e+01, l2_regularization 3.21e-01
# -------------------------- 228 --------------------------
# Lambda_ = 17.92, selected 1000 features
# 10 epochs, val_objective 1.01e+01, val_loss 2.76e-06, regularization 1.01e+01, l2_regularization 3.21e-01
# -------------------------- 229 --------------------------
# Lambda_ = 18.28, selected 1000 features
# 10 epochs, val_objective 1.03e+01, val_loss 2.79e-06, regularization 1.03e+01, l2_regularization 3.21e-01
# -------------------------- 230 --------------------------
# Lambda_ = 18.64, selected 1000 features
# 10 epochs, val_objective 1.04e+01, val_loss 2.81e-06, regularization 1.04e+01, l2_regularization 3.21e-01
# -------------------------- 231 --------------------------
# Lambda_ = 19.01, selected 1000 features
# 10 epochs, val_objective 1.05e+01, val_loss 2.84e-06, regularization 1.05e+01, l2_regularization 3.21e-01
# -------------------------- 232 --------------------------
# Lambda_ = 19.39, selected 1000 features
# 10 epochs, val_objective 1.07e+01, val_loss 2.86e-06, regularization 1.07e+01, l2_regularization 3.21e-01
# -------------------------- 233 --------------------------
# Lambda_ = 19.78, selected 1000 features
# 10 epochs, val_objective 1.08e+01, val_loss 2.89e-06, regularization 1.08e+01, l2_regularization 3.21e-01
# -------------------------- 234 --------------------------
# Lambda_ = 20.18, selected 1000 features
# 10 epochs, val_objective 1.09e+01, val_loss 2.91e-06, regularization 1.09e+01, l2_regularization 3.21e-01
# -------------------------- 235 --------------------------
# Lambda_ = 20.58, selected 1000 features
# 10 epochs, val_objective 1.11e+01, val_loss 2.94e-06, regularization 1.11e+01, l2_regularization 3.21e-01
# -------------------------- 236 --------------------------
# Lambda_ = 20.99, selected 1000 features
# 10 epochs, val_objective 1.12e+01, val_loss 2.97e-06, regularization 1.12e+01, l2_regularization 3.21e-01
# -------------------------- 237 --------------------------
# Lambda_ = 21.41, selected 1000 features
# 10 epochs, val_objective 1.13e+01, val_loss 3.00e-06, regularization 1.13e+01, l2_regularization 3.21e-01
# -------------------------- 238 --------------------------
# Lambda_ = 21.84, selected 1000 features
# 10 epochs, val_objective 1.15e+01, val_loss 3.02e-06, regularization 1.15e+01, l2_regularization 3.21e-01
# -------------------------- 239 --------------------------
# Lambda_ = 22.28, selected 1000 features
# 10 epochs, val_objective 1.16e+01, val_loss 3.05e-06, regularization 1.16e+01, l2_regularization 3.21e-01
# -------------------------- 240 --------------------------
# Lambda_ = 22.72, selected 996 features
# 100 epochs, val_objective 1.59e+00, val_loss 4.86e-06, regularization 1.59e+00, l2_regularization 3.21e-01
# -------------------------- 241 --------------------------
# Lambda_ = 23.18, selected 436 features
# 100 epochs, val_objective 1.52e-01, val_loss 1.10e-05, regularization 1.52e-01, l2_regularization 3.21e-01
# -------------------------- 242 --------------------------
# Lambda_ = 23.64, selected 81 features
# 100 epochs, val_objective 2.33e-02, val_loss 1.13e-05, regularization 2.33e-02, l2_regularization 3.22e-01

# %%
# # LassoNet
# fig_name = "LassoNet"
# model = lassonet.LassoNetRegressor(
#     hidden_dims=(100,),
#     path_multiplier=1.005,   # 控制Lambda_1变化趋势
#     verbose=False,
#     patience=(100, 5)
# )
# path = model.path(X_train, y_train)
# index = -2
# weight = abs(np.array(path[index].state_dict['skip.weight'][0]))
# importances = weight / sum(weight)

# %%
# # Lasso
# fig_name = "Lasso"
# model = Lasso(alpha=0.001)
# model.fit(X_train, y_train)
# importances = abs(model.coef_) / np.sum(abs(model.coef_))

# %%
# # Group Lasso
# # fig_name = "GroupLasso"
# # model = GroupLassoRegressor(group_ids=group_array, random_state=42, verbose=False, alpha=0.0001)
# # model.fit(X_train, y_train)
# # importances = abs(model.coef_) / np.sum(abs(model.coef_))
# fig_name = "GroupLasso"
# model = SGL(
#     groups=Groups, l1_ratio=0, alpha=0.02431).fit(X_train, y_train)
# importances = abs(model.coef_) / np.sum(abs(model.coef_))

# %%
# # Sparse Group Lasso
# fig_name = "SGL"
# model = SGL(
#     groups=Groups, l1_ratio=0.5, alpha=0).fit(X_train, y_train)
# importances = abs(model.coef_) / np.sum(abs(model.coef_))

# %%
# 绘制测试数据的散点图
from matplotlib.pyplot import MultipleLocator
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

index = -2
weight = abs(np.array(path[index].state_dict['skip.weight'][0]))
importances = weight / sum(weight)
num = np.count_nonzero(importances)
print(str(fig_name) + ": " + str(num))


x=[]
y=[]


df = importances / importances.max()


# df = (importances - importances.min()) / (importances.max() - importances.min())
for i in range(len(df)):
    if df[i] != 0:
        yi = [df[i], -0.15]
        y.append(yi)
        xi = [i,i]
        x.append(xi)

config = {
    "font.family": 'Times New Roman',
    "font.size": 12
}

rcParams.update(config)
plt.figure(dpi=100, figsize=(8, 6))

rng = np.random.RandomState(0)
colors = rng.rand(len(df))  # 随机产生50个用于颜色映射的数值
for i in range(len(x)):
    plt.scatter(x[i], y[i], color='black', s=5)
    plt.plot(x[i], y[i])


# 设置x轴刻度
x_major_locator = MultipleLocator(sample_num)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)

plt.xlim(0, 1000)
plt.ylim(df.min(), df.max())

# plt.title("The feature importance of the picture '0'")
# plt.title(fig_name + ": Select " + str(num) + " features")
plt.savefig("figures/alpha/" + "alpha0.2" + ".pdf", bbox_inches='tight')
plt.show()
# Out:
# SGLN: 436

# %%
classify_weight = []
for i in range(0, 10):
     w = float(format(sum(importances[i*100: (i+1)*100]) / sum(importances), '.3f'))
     classify_weight.append(w)
print(classify_weight)
# Out:
# [0.695, 0.011, 0.056, 0.002, 0.041, 0.04, 0.045, 0.051, 0.009, 0.051]
